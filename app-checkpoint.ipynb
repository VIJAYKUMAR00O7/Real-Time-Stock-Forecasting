# %%
pip install statsmodels
# Out:
# Requirement already satisfied: statsmodels in e:\anaconda\envs\spark\lib\site-packages (0.14.5)
# Requirement already satisfied: numpy<3,>=1.22.3 in e:\anaconda\envs\spark\lib\site-packages (from statsmodels) (2.1.3)
# Requirement already satisfied: scipy!=1.9.2,>=1.8 in e:\anaconda\envs\spark\lib\site-packages (from statsmodels) (1.16.1)
# Requirement already satisfied: pandas!=2.1.0,>=1.4 in e:\anaconda\envs\spark\lib\site-packages (from statsmodels) (2.3.1)
# Requirement already satisfied: patsy>=0.5.6 in e:\anaconda\envs\spark\lib\site-packages (from statsmodels) (1.0.1)
# Requirement already satisfied: packaging>=21.3 in e:\anaconda\envs\spark\lib\site-packages (from statsmodels) (24.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in e:\anaconda\envs\spark\lib\site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in e:\anaconda\envs\spark\lib\site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in e:\anaconda\envs\spark\lib\site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2025.2)
# Requirement already satisfied: six>=1.5 in e:\anaconda\envs\spark\lib\site-packages (from python-dateutil>=2.8.2->pandas!=2.1.0,>=1.4->statsmodels) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install streamlit
# Out:
# Requirement already satisfied: streamlit in e:\anaconda\envs\spark\lib\site-packages (1.47.1)
# Requirement already satisfied: altair<6,>=4.0 in e:\anaconda\envs\spark\lib\site-packages (from streamlit) (5.5.0)
# Requirement already satisfied: blinker<2,>=1.5.0 in e:\anaconda\envs\spark\lib\site-packages (from streamlit) (1.9.0)
# Requirement already satisfied: cachetools<7,>=4.0 in e:\anaconda\envs\spark\lib\site-packages (from streamlit) (6.1.0)
# Requirement already satisfied: click<9,>=7.0 in e:\anaconda\envs\spark\lib\site-packages (from streamlit) (8.2.1)
# Requirement already satisfied: numpy<3,>=1.23 in e:\anaconda\envs\spark\lib\site-packages (from streamlit) (2.1.3)
# Requirement already satisfied: packaging<26,>=20 in e:\anaconda\envs\spark\lib\site-packages (from streamlit) (24.2)
# Requirement already satisfied: pandas<3,>=1.4.0 in e:\anaconda\envs\spark\lib\site-packages (from streamlit) (2.3.1)
# Requirement already satisfied: pillow<12,>=7.1.0 in e:\anaconda\envs\spark\lib\site-packages (from streamlit) (11.3.0)
# Requirement already satisfied: protobuf<7,>=3.20 in e:\anaconda\envs\spark\lib\site-packages (from streamlit) (5.29.5)
# Requirement already satisfied: pyarrow>=7.0 in e:\anaconda\envs\spark\lib\site-packages (from streamlit) (21.0.0)
# Requirement already satisfied: requests<3,>=2.27 in e:\anaconda\envs\spark\lib\site-packages (from streamlit) (2.32.4)
# Requirement already satisfied: tenacity<10,>=8.1.0 in e:\anaconda\envs\spark\lib\site-packages (from streamlit) (9.1.2)
# Requirement already satisfied: toml<2,>=0.10.1 in e:\anaconda\envs\spark\lib\site-packages (from streamlit) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.4.0 in e:\anaconda\envs\spark\lib\site-packages (from streamlit) (4.12.2)
# Requirement already satisfied: watchdog<7,>=2.1.5 in e:\anaconda\envs\spark\lib\site-packages (from streamlit) (6.0.0)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in e:\anaconda\envs\spark\lib\site-packages (from streamlit) (3.1.45)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in e:\anaconda\envs\spark\lib\site-packages (from streamlit) (0.9.1)
# Requirement already satisfied: tornado!=6.5.0,<7,>=6.0.3 in e:\anaconda\envs\spark\lib\site-packages (from streamlit) (6.5.1)
# Requirement already satisfied: jinja2 in e:\anaconda\envs\spark\lib\site-packages (from altair<6,>=4.0->streamlit) (3.1.6)
# Requirement already satisfied: jsonschema>=3.0 in e:\anaconda\envs\spark\lib\site-packages (from altair<6,>=4.0->streamlit) (4.23.0)
# Requirement already satisfied: narwhals>=1.14.2 in e:\anaconda\envs\spark\lib\site-packages (from altair<6,>=4.0->streamlit) (2.0.1)
# Requirement already satisfied: colorama in e:\anaconda\envs\spark\lib\site-packages (from click<9,>=7.0->streamlit) (0.4.6)
# Requirement already satisfied: gitdb<5,>=4.0.1 in e:\anaconda\envs\spark\lib\site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.12)
# Requirement already satisfied: smmap<6,>=3.0.1 in e:\anaconda\envs\spark\lib\site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit) (5.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in e:\anaconda\envs\spark\lib\site-packages (from pandas<3,>=1.4.0->streamlit) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in e:\anaconda\envs\spark\lib\site-packages (from pandas<3,>=1.4.0->streamlit) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in e:\anaconda\envs\spark\lib\site-packages (from pandas<3,>=1.4.0->streamlit) (2025.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in e:\anaconda\envs\spark\lib\site-packages (from requests<3,>=2.27->streamlit) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in e:\anaconda\envs\spark\lib\site-packages (from requests<3,>=2.27->streamlit) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in e:\anaconda\envs\spark\lib\site-packages (from requests<3,>=2.27->streamlit) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in e:\anaconda\envs\spark\lib\site-packages (from requests<3,>=2.27->streamlit) (2025.6.15)
# Requirement already satisfied: MarkupSafe>=2.0 in e:\anaconda\envs\spark\lib\site-packages (from jinja2->altair<6,>=4.0->streamlit) (3.0.2)
# Requirement already satisfied: attrs>=22.2.0 in e:\anaconda\envs\spark\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (24.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in e:\anaconda\envs\spark\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in e:\anaconda\envs\spark\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in e:\anaconda\envs\spark\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.22.3)
# Requirement already satisfied: six>=1.5 in e:\anaconda\envs\spark\lib\site-packages (from python-dateutil>=2.8.2->pandas<3,>=1.4.0->streamlit) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install yfinance
# Out:
# Requirement already satisfied: yfinance in e:\anaconda\envs\spark\lib\site-packages (0.2.65)
# Requirement already satisfied: pandas>=1.3.0 in e:\anaconda\envs\spark\lib\site-packages (from yfinance) (2.3.1)
# Requirement already satisfied: numpy>=1.16.5 in e:\anaconda\envs\spark\lib\site-packages (from yfinance) (2.1.3)
# Requirement already satisfied: requests>=2.31 in e:\anaconda\envs\spark\lib\site-packages (from yfinance) (2.32.4)
# Requirement already satisfied: multitasking>=0.0.7 in e:\anaconda\envs\spark\lib\site-packages (from yfinance) (0.0.12)
# Requirement already satisfied: platformdirs>=2.0.0 in e:\anaconda\envs\spark\lib\site-packages (from yfinance) (4.3.7)
# Requirement already satisfied: pytz>=2022.5 in e:\anaconda\envs\spark\lib\site-packages (from yfinance) (2025.2)
# Requirement already satisfied: frozendict>=2.3.4 in e:\anaconda\envs\spark\lib\site-packages (from yfinance) (2.4.6)
# Requirement already satisfied: peewee>=3.16.2 in e:\anaconda\envs\spark\lib\site-packages (from yfinance) (3.18.2)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in e:\anaconda\envs\spark\lib\site-packages (from yfinance) (4.12.3)
# Requirement already satisfied: curl_cffi>=0.7 in e:\anaconda\envs\spark\lib\site-packages (from yfinance) (0.12.0)
# Requirement already satisfied: protobuf>=3.19.0 in e:\anaconda\envs\spark\lib\site-packages (from yfinance) (5.29.5)
# Requirement already satisfied: websockets>=13.0 in e:\anaconda\envs\spark\lib\site-packages (from yfinance) (15.0.1)
# Requirement already satisfied: soupsieve>1.2 in e:\anaconda\envs\spark\lib\site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.5)
# Requirement already satisfied: cffi>=1.12.0 in e:\anaconda\envs\spark\lib\site-packages (from curl_cffi>=0.7->yfinance) (1.17.1)
# Requirement already satisfied: certifi>=2024.2.2 in e:\anaconda\envs\spark\lib\site-packages (from curl_cffi>=0.7->yfinance) (2025.6.15)
# Requirement already satisfied: pycparser in e:\anaconda\envs\spark\lib\site-packages (from cffi>=1.12.0->curl_cffi>=0.7->yfinance) (2.21)
# Requirement already satisfied: python-dateutil>=2.8.2 in e:\anaconda\envs\spark\lib\site-packages (from pandas>=1.3.0->yfinance) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in e:\anaconda\envs\spark\lib\site-packages (from pandas>=1.3.0->yfinance) (2025.2)
# Requirement already satisfied: six>=1.5 in e:\anaconda\envs\spark\lib\site-packages (from python-dateutil>=2.8.2->pandas>=1.3.0->yfinance) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in e:\anaconda\envs\spark\lib\site-packages (from requests>=2.31->yfinance) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in e:\anaconda\envs\spark\lib\site-packages (from requests>=2.31->yfinance) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in e:\anaconda\envs\spark\lib\site-packages (from requests>=2.31->yfinance) (2.5.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pandas
# Out:
# Requirement already satisfied: pandas in e:\anaconda\envs\spark\lib\site-packages (2.3.1)
# Requirement already satisfied: numpy>=1.23.2 in e:\anaconda\envs\spark\lib\site-packages (from pandas) (2.1.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in e:\anaconda\envs\spark\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in e:\anaconda\envs\spark\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in e:\anaconda\envs\spark\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in e:\anaconda\envs\spark\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install numpy
# Out:
# Requirement already satisfied: numpy in e:\anaconda\envs\spark\lib\site-packages (2.1.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install plotly
# Out:
# Requirement already satisfied: plotly in e:\anaconda\envs\spark\lib\site-packages (6.2.0)
# Requirement already satisfied: narwhals>=1.15.1 in e:\anaconda\envs\spark\lib\site-packages (from plotly) (2.0.1)
# Requirement already satisfied: packaging in e:\anaconda\envs\spark\lib\site-packages (from plotly) (24.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install numpy pandas yfinance streamlit plotly --no-cache-dir
# Out:
# Requirement already satisfied: numpy in e:\anaconda\envs\spark\lib\site-packages (2.1.3)
# Requirement already satisfied: pandas in e:\anaconda\envs\spark\lib\site-packages (2.3.1)
# Requirement already satisfied: yfinance in e:\anaconda\envs\spark\lib\site-packages (0.2.65)
# Requirement already satisfied: streamlit in e:\anaconda\envs\spark\lib\site-packages (1.47.1)
# Requirement already satisfied: plotly in e:\anaconda\envs\spark\lib\site-packages (6.2.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in e:\anaconda\envs\spark\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in e:\anaconda\envs\spark\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in e:\anaconda\envs\spark\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: requests>=2.31 in e:\anaconda\envs\spark\lib\site-packages (from yfinance) (2.32.4)
# Requirement already satisfied: multitasking>=0.0.7 in e:\anaconda\envs\spark\lib\site-packages (from yfinance) (0.0.12)
# Requirement already satisfied: platformdirs>=2.0.0 in e:\anaconda\envs\spark\lib\site-packages (from yfinance) (4.3.7)
# Requirement already satisfied: frozendict>=2.3.4 in e:\anaconda\envs\spark\lib\site-packages (from yfinance) (2.4.6)
# Requirement already satisfied: peewee>=3.16.2 in e:\anaconda\envs\spark\lib\site-packages (from yfinance) (3.18.2)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in e:\anaconda\envs\spark\lib\site-packages (from yfinance) (4.12.3)
# Requirement already satisfied: curl_cffi>=0.7 in e:\anaconda\envs\spark\lib\site-packages (from yfinance) (0.12.0)
# Requirement already satisfied: protobuf>=3.19.0 in e:\anaconda\envs\spark\lib\site-packages (from yfinance) (5.29.5)
# Requirement already satisfied: websockets>=13.0 in e:\anaconda\envs\spark\lib\site-packages (from yfinance) (15.0.1)
# Requirement already satisfied: altair<6,>=4.0 in e:\anaconda\envs\spark\lib\site-packages (from streamlit) (5.5.0)
# Requirement already satisfied: blinker<2,>=1.5.0 in e:\anaconda\envs\spark\lib\site-packages (from streamlit) (1.9.0)
# Requirement already satisfied: cachetools<7,>=4.0 in e:\anaconda\envs\spark\lib\site-packages (from streamlit) (6.1.0)
# Requirement already satisfied: click<9,>=7.0 in e:\anaconda\envs\spark\lib\site-packages (from streamlit) (8.2.1)
# Requirement already satisfied: packaging<26,>=20 in e:\anaconda\envs\spark\lib\site-packages (from streamlit) (24.2)
# Requirement already satisfied: pillow<12,>=7.1.0 in e:\anaconda\envs\spark\lib\site-packages (from streamlit) (11.3.0)
# Requirement already satisfied: pyarrow>=7.0 in e:\anaconda\envs\spark\lib\site-packages (from streamlit) (21.0.0)
# Requirement already satisfied: tenacity<10,>=8.1.0 in e:\anaconda\envs\spark\lib\site-packages (from streamlit) (9.1.2)
# Requirement already satisfied: toml<2,>=0.10.1 in e:\anaconda\envs\spark\lib\site-packages (from streamlit) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.4.0 in e:\anaconda\envs\spark\lib\site-packages (from streamlit) (4.12.2)
# Requirement already satisfied: watchdog<7,>=2.1.5 in e:\anaconda\envs\spark\lib\site-packages (from streamlit) (6.0.0)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in e:\anaconda\envs\spark\lib\site-packages (from streamlit) (3.1.45)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in e:\anaconda\envs\spark\lib\site-packages (from streamlit) (0.9.1)
# Requirement already satisfied: tornado!=6.5.0,<7,>=6.0.3 in e:\anaconda\envs\spark\lib\site-packages (from streamlit) (6.5.1)
# Requirement already satisfied: jinja2 in e:\anaconda\envs\spark\lib\site-packages (from altair<6,>=4.0->streamlit) (3.1.6)
# Requirement already satisfied: jsonschema>=3.0 in e:\anaconda\envs\spark\lib\site-packages (from altair<6,>=4.0->streamlit) (4.23.0)
# Requirement already satisfied: narwhals>=1.14.2 in e:\anaconda\envs\spark\lib\site-packages (from altair<6,>=4.0->streamlit) (2.0.1)
# Requirement already satisfied: colorama in e:\anaconda\envs\spark\lib\site-packages (from click<9,>=7.0->streamlit) (0.4.6)
# Requirement already satisfied: gitdb<5,>=4.0.1 in e:\anaconda\envs\spark\lib\site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.12)
# Requirement already satisfied: smmap<6,>=3.0.1 in e:\anaconda\envs\spark\lib\site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit) (5.0.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in e:\anaconda\envs\spark\lib\site-packages (from requests>=2.31->yfinance) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in e:\anaconda\envs\spark\lib\site-packages (from requests>=2.31->yfinance) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in e:\anaconda\envs\spark\lib\site-packages (from requests>=2.31->yfinance) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in e:\anaconda\envs\spark\lib\site-packages (from requests>=2.31->yfinance) (2025.6.15)
# Requirement already satisfied: soupsieve>1.2 in e:\anaconda\envs\spark\lib\site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.5)
# Requirement already satisfied: cffi>=1.12.0 in e:\anaconda\envs\spark\lib\site-packages (from curl_cffi>=0.7->yfinance) (1.17.1)
# Requirement already satisfied: pycparser in e:\anaconda\envs\spark\lib\site-packages (from cffi>=1.12.0->curl_cffi>=0.7->yfinance) (2.21)
# Requirement already satisfied: MarkupSafe>=2.0 in e:\anaconda\envs\spark\lib\site-packages (from jinja2->altair<6,>=4.0->streamlit) (3.0.2)
# Requirement already satisfied: attrs>=22.2.0 in e:\anaconda\envs\spark\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (24.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in e:\anaconda\envs\spark\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in e:\anaconda\envs\spark\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in e:\anaconda\envs\spark\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.22.3)
# Requirement already satisfied: six>=1.5 in e:\anaconda\envs\spark\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in e:\anaconda\envs\spark\lib\site-packages (1.7.1)
# Requirement already satisfied: numpy>=1.22.0 in e:\anaconda\envs\spark\lib\site-packages (from scikit-learn) (2.1.3)
# Requirement already satisfied: scipy>=1.8.0 in e:\anaconda\envs\spark\lib\site-packages (from scikit-learn) (1.16.1)
# Requirement already satisfied: joblib>=1.2.0 in e:\anaconda\envs\spark\lib\site-packages (from scikit-learn) (1.5.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in e:\anaconda\envs\spark\lib\site-packages (from scikit-learn) (3.6.0)

# %%
pip install xgboost
# Out:
# Collecting xgboost
#   Using cached xgboost-3.0.3-py3-none-win_amd64.whl.metadata (2.1 kB)
# Requirement already satisfied: numpy in e:\anaconda\envs\spark\lib\site-packages (from xgboost) (2.1.3)
# Requirement already satisfied: scipy in e:\anaconda\envs\spark\lib\site-packages (from xgboost) (1.16.1)
# Downloading xgboost-3.0.3-py3-none-win_amd64.whl (149.9 MB)
#    ---------------------------------------- 0.0/149.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/149.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/149.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/149.9 MB ? eta -:--:--
#    ---------------------------------------- 0.3/149.9 MB ? eta -:--:--
#    ---------------------------------------- 0.3/149.9 MB ? eta -:--:--
#    ---------------------------------------- 0.3/149.9 MB ? eta -:--:--
#    ---------------------------------------- 0.3/149.9 MB ? eta -:--:--
#    ---------------------------------------- 0.5/149.9 MB 399.6 kB/s eta 0:06:14
#    ---------------------------------------- 0.8/149.9 MB 541.1 kB/s eta 0:04:36
#    ---------------------------------------- 0.8/149.9 MB 541.1 kB/s eta 0:04:36
#    ---------------------------------------- 1.0/149.9 MB 578.7 kB/s eta 0:04:18
#    ---------------------------------------- 1.0/149.9 MB 578.7 kB/s eta 0:04:18
#    ---------------------------------------- 1.3/149.9 MB 621.6 kB/s eta 0:04:00
#    ---------------------------------------- 1.3/149.9 MB 621.6 kB/s eta 0:04:00
#    ---------------------------------------- 1.6/149.9 MB 586.7 kB/s eta 0:04:13
#    ---------------------------------------- 1.6/149.9 MB 586.7 kB/s eta 0:04:13
#    ---------------------------------------- 1.6/149.9 MB 586.7 kB/s eta 0:04:13
#    ---------------------------------------- 1.6/149.9 MB 586.7 kB/s eta 0:04:13
#    ---------------------------------------- 1.6/149.9 MB 586.7 kB/s eta 0:04:13
#    ---------------------------------------- 1.6/149.9 MB 586.7 kB/s eta 0:04:13
#    ---------------------------------------- 1.6/149.9 MB 586.7 kB/s eta 0:04:13
#    ---------------------------------------- 1.8/149.9 MB 435.8 kB/s eta 0:05:40
#    ---------------------------------------- 1.8/149.9 MB 435.8 kB/s eta 0:05:40
#     --------------------------------------- 2.1/149.9 MB 444.9 kB/s eta 0:05:33
#     --------------------------------------- 2.1/149.9 MB 444.9 kB/s eta 0:05:33
#     --------------------------------------- 2.4/149.9 MB 469.3 kB/s eta 0:05:15
#     --------------------------------------- 2.4/149.9 MB 469.3 kB/s eta 0:05:15
#     --------------------------------------- 2.4/149.9 MB 469.3 kB/s eta 0:05:15
#     --------------------------------------- 2.6/149.9 MB 469.0 kB/s eta 0:05:15
#     --------------------------------------- 2.6/149.9 MB 469.0 kB/s eta 0:05:15
#     --------------------------------------- 2.6/149.9 MB 469.0 kB/s eta 0:05:15
#     --------------------------------------- 2.6/149.9 MB 469.0 kB/s eta 0:05:15
#     --------------------------------------- 2.6/149.9 MB 469.0 kB/s eta 0:05:15
#     --------------------------------------- 2.9/149.9 MB 433.5 kB/s eta 0:05:40
#     --------------------------------------- 2.9/149.9 MB 433.5 kB/s eta 0:05:40
#     --------------------------------------- 2.9/149.9 MB 433.5 kB/s eta 0:05:40
#     --------------------------------------- 2.9/149.9 MB 433.5 kB/s eta 0:05:40
#     --------------------------------------- 2.9/149.9 MB 433.5 kB/s eta 0:05:40
#     --------------------------------------- 2.9/149.9 MB 433.5 kB/s eta 0:05:40
#     --------------------------------------- 2.9/149.9 MB 433.5 kB/s eta 0:05:40
#     --------------------------------------- 2.9/149.9 MB 433.5 kB/s eta 0:05:40
#     --------------------------------------- 2.9/149.9 MB 433.5 kB/s eta 0:05:40
#     --------------------------------------- 3.1/149.9 MB 366.2 kB/s eta 0:06:41
#     --------------------------------------- 3.1/149.9 MB 366.2 kB/s eta 0:06:41
#     --------------------------------------- 3.1/149.9 MB 366.2 kB/s eta 0:06:41
#     --------------------------------------- 3.1/149.9 MB 366.2 kB/s eta 0:06:41
#     --------------------------------------- 3.1/149.9 MB 366.2 kB/s eta 0:06:41
#     --------------------------------------- 3.1/149.9 MB 366.2 kB/s eta 0:06:41
#     --------------------------------------- 3.1/149.9 MB 366.2 kB/s eta 0:06:41
#     --------------------------------------- 3.1/149.9 MB 366.2 kB/s eta 0:06:41
#     --------------------------------------- 3.1/149.9 MB 366.2 kB/s eta 0:06:41
#     --------------------------------------- 3.1/149.9 MB 366.2 kB/s eta 0:06:41
#     --------------------------------------- 3.1/149.9 MB 366.2 kB/s eta 0:06:41
#     --------------------------------------- 3.1/149.9 MB 366.2 kB/s eta 0:06:41
#     --------------------------------------- 3.1/149.9 MB 366.2 kB/s eta 0:06:41
#     --------------------------------------- 3.1/149.9 MB 366.2 kB/s eta 0:06:41
#     --------------------------------------- 3.1/149.9 MB 366.2 kB/s eta 0:06:41
#     --------------------------------------- 3.1/149.9 MB 366.2 kB/s eta 0:06:41
#     --------------------------------------- 3.4/149.9 MB 277.3 kB/s eta 0:08:49
#     --------------------------------------- 3.7/149.9 MB 295.5 kB/s eta 0:08:15
#    - -------------------------------------- 3.9/149.9 MB 314.0 kB/s eta 0:07:45
#    - -------------------------------------- 4.5/149.9 MB 350.4 kB/s eta 0:06:56
#    - -------------------------------------- 4.7/149.9 MB 368.5 kB/s eta 0:06:34
#    - -------------------------------------- 5.2/149.9 MB 404.0 kB/s eta 0:05:59
#    - -------------------------------------- 5.8/149.9 MB 436.6 kB/s eta 0:05:31
#    - -------------------------------------- 6.0/149.9 MB 450.1 kB/s eta 0:05:20
#    - -------------------------------------- 6.3/149.9 MB 464.9 kB/s eta 0:05:09
#    - -------------------------------------- 7.1/149.9 MB 515.6 kB/s eta 0:04:37
#    -- ------------------------------------- 7.6/149.9 MB 548.8 kB/s eta 0:04:20
#    -- ------------------------------------- 8.7/149.9 MB 616.4 kB/s eta 0:03:50
#    -- ------------------------------------- 9.2/149.9 MB 648.2 kB/s eta 0:03:38
#    -- ------------------------------------ 10.0/149.9 MB 694.3 kB/s eta 0:03:22
#    -- ------------------------------------ 11.3/149.9 MB 772.6 kB/s eta 0:03:00
#    --- ----------------------------------- 12.3/149.9 MB 835.3 kB/s eta 0:02:45
#    --- ----------------------------------- 13.6/149.9 MB 913.1 kB/s eta 0:02:30
#    --- ----------------------------------- 14.9/149.9 MB 990.0 kB/s eta 0:02:17
#    ---- ----------------------------------- 16.3/149.9 MB 1.1 MB/s eta 0:02:06
#    ---- ----------------------------------- 17.8/149.9 MB 1.2 MB/s eta 0:01:55
#    ----- ---------------------------------- 19.4/149.9 MB 1.2 MB/s eta 0:01:46
#    ----- ---------------------------------- 20.2/149.9 MB 1.3 MB/s eta 0:01:43
#    ----- ---------------------------------- 21.8/149.9 MB 1.4 MB/s eta 0:01:35
#    ------ --------------------------------- 22.8/149.9 MB 1.4 MB/s eta 0:01:31
#    ------ --------------------------------- 23.9/149.9 MB 1.4 MB/s eta 0:01:28
#    ------ --------------------------------- 25.4/149.9 MB 1.5 MB/s eta 0:01:22
#    ------- -------------------------------- 27.3/149.9 MB 1.6 MB/s eta 0:01:16
#    ------- -------------------------------- 28.8/149.9 MB 1.7 MB/s eta 0:01:12
#    -------- ------------------------------- 30.1/149.9 MB 1.7 MB/s eta 0:01:09
#    -------- ------------------------------- 31.7/149.9 MB 1.8 MB/s eta 0:01:06
#    -------- ------------------------------- 32.8/149.9 MB 1.9 MB/s eta 0:01:04
#    --------- ------------------------------ 34.1/149.9 MB 1.9 MB/s eta 0:01:01
#    --------- ------------------------------ 35.7/149.9 MB 2.0 MB/s eta 0:00:59
#    --------- ------------------------------ 37.0/149.9 MB 2.0 MB/s eta 0:00:56
#    ---------- ----------------------------- 38.5/149.9 MB 2.1 MB/s eta 0:00:54
#    ---------- ----------------------------- 39.8/149.9 MB 2.1 MB/s eta 0:00:52
#    ---------- ----------------------------- 40.6/149.9 MB 2.2 MB/s eta 0:00:51
#    ----------- ---------------------------- 41.7/149.9 MB 2.2 MB/s eta 0:00:50
#    ----------- ---------------------------- 42.7/149.9 MB 2.2 MB/s eta 0:00:49
#    ----------- ---------------------------- 43.8/149.9 MB 2.2 MB/s eta 0:00:48
#    ----------- ---------------------------- 44.6/149.9 MB 2.3 MB/s eta 0:00:47
#    ------------ --------------------------- 45.4/149.9 MB 2.3 MB/s eta 0:00:46
#    ------------ --------------------------- 45.6/149.9 MB 2.3 MB/s eta 0:00:46
#    ------------ --------------------------- 46.1/149.9 MB 2.3 MB/s eta 0:00:46
#    ------------ --------------------------- 46.4/149.9 MB 2.3 MB/s eta 0:00:46
#    ------------ --------------------------- 46.4/149.9 MB 2.3 MB/s eta 0:00:46
#    ------------ --------------------------- 46.4/149.9 MB 2.3 MB/s eta 0:00:46
#    ------------ --------------------------- 46.7/149.9 MB 2.2 MB/s eta 0:00:47
#    ------------ --------------------------- 46.7/149.9 MB 2.2 MB/s eta 0:00:47
#    ------------ --------------------------- 46.7/149.9 MB 2.2 MB/s eta 0:00:47
#    ------------ --------------------------- 46.9/149.9 MB 2.2 MB/s eta 0:00:48
#    ------------ --------------------------- 47.2/149.9 MB 2.1 MB/s eta 0:00:48
#    ------------ --------------------------- 47.4/149.9 MB 2.1 MB/s eta 0:00:49
#    ------------ --------------------------- 47.7/149.9 MB 2.1 MB/s eta 0:00:49
#    ------------ --------------------------- 47.7/149.9 MB 2.1 MB/s eta 0:00:49
#    ------------ --------------------------- 48.0/149.9 MB 2.1 MB/s eta 0:00:49
#    ------------ --------------------------- 48.2/149.9 MB 2.1 MB/s eta 0:00:49
#    ------------ --------------------------- 48.5/149.9 MB 2.1 MB/s eta 0:00:49
#    ------------- -------------------------- 48.8/149.9 MB 2.1 MB/s eta 0:00:49
#    ------------- -------------------------- 49.3/149.9 MB 2.1 MB/s eta 0:00:49
#    ------------- -------------------------- 49.8/149.9 MB 2.1 MB/s eta 0:00:49
#    ------------- -------------------------- 50.6/149.9 MB 2.1 MB/s eta 0:00:48
#    ------------- -------------------------- 51.6/149.9 MB 2.1 MB/s eta 0:00:47
#    -------------- ------------------------- 52.7/149.9 MB 2.1 MB/s eta 0:00:46
#    -------------- ------------------------- 53.7/149.9 MB 2.2 MB/s eta 0:00:45
#    -------------- ------------------------- 55.1/149.9 MB 2.2 MB/s eta 0:00:44
#    -------------- ------------------------- 56.1/149.9 MB 2.2 MB/s eta 0:00:43
#    --------------- ------------------------ 57.4/149.9 MB 2.3 MB/s eta 0:00:41
#    --------------- ------------------------ 58.7/149.9 MB 2.3 MB/s eta 0:00:40
#    --------------- ------------------------ 59.8/149.9 MB 2.3 MB/s eta 0:00:39
#    ---------------- ----------------------- 61.1/149.9 MB 2.3 MB/s eta 0:00:38
#    ---------------- ----------------------- 62.4/149.9 MB 2.4 MB/s eta 0:00:37
#    ----------------- ---------------------- 64.0/149.9 MB 2.4 MB/s eta 0:00:36
#    ----------------- ---------------------- 65.5/149.9 MB 2.5 MB/s eta 0:00:35
#    ----------------- ---------------------- 66.8/149.9 MB 2.5 MB/s eta 0:00:34
#    ------------------ --------------------- 68.7/149.9 MB 2.5 MB/s eta 0:00:32
#    ------------------ --------------------- 70.3/149.9 MB 2.6 MB/s eta 0:00:31
#    ------------------- -------------------- 71.8/149.9 MB 2.6 MB/s eta 0:00:30
#    ------------------- -------------------- 73.7/149.9 MB 2.7 MB/s eta 0:00:29
#    -------------------- ------------------- 75.2/149.9 MB 2.7 MB/s eta 0:00:28
#    -------------------- ------------------- 76.8/149.9 MB 2.7 MB/s eta 0:00:27
#    -------------------- ------------------- 78.6/149.9 MB 2.8 MB/s eta 0:00:26
#    --------------------- ------------------ 80.5/149.9 MB 2.8 MB/s eta 0:00:25
#    --------------------- ------------------ 81.8/149.9 MB 2.9 MB/s eta 0:00:24
#    ---------------------- ----------------- 82.8/149.9 MB 2.9 MB/s eta 0:00:24
#    ---------------------- ----------------- 84.4/149.9 MB 2.9 MB/s eta 0:00:23
#    ----------------------- ---------------- 86.2/149.9 MB 2.9 MB/s eta 0:00:22
#    ----------------------- ---------------- 88.1/149.9 MB 3.0 MB/s eta 0:00:21
#    ----------------------- ---------------- 89.9/149.9 MB 3.0 MB/s eta 0:00:20
#    ------------------------ --------------- 91.5/149.9 MB 3.1 MB/s eta 0:00:20
#    ------------------------ --------------- 93.1/149.9 MB 3.2 MB/s eta 0:00:19
#    ------------------------- -------------- 94.1/149.9 MB 3.2 MB/s eta 0:00:18
#    ------------------------- -------------- 95.4/149.9 MB 3.2 MB/s eta 0:00:18
#    ------------------------- -------------- 97.0/149.9 MB 3.2 MB/s eta 0:00:17
#    -------------------------- ------------- 98.8/149.9 MB 3.3 MB/s eta 0:00:16
#    -------------------------- ------------- 100.4/149.9 MB 3.4 MB/s eta 0:00:15
#    --------------------------- ------------ 102.2/149.9 MB 3.4 MB/s eta 0:00:15
#    --------------------------- ------------ 103.8/149.9 MB 3.4 MB/s eta 0:00:14
#    ---------------------------- ----------- 105.1/149.9 MB 3.5 MB/s eta 0:00:13
#    ---------------------------- ----------- 106.4/149.9 MB 3.5 MB/s eta 0:00:13
#    ---------------------------- ----------- 108.0/149.9 MB 3.6 MB/s eta 0:00:12
#    ----------------------------- ---------- 109.6/149.9 MB 3.8 MB/s eta 0:00:11
#    ----------------------------- ---------- 111.4/149.9 MB 3.8 MB/s eta 0:00:11
#    ------------------------------ --------- 113.2/149.9 MB 3.8 MB/s eta 0:00:10
#    ------------------------------ --------- 114.6/149.9 MB 3.8 MB/s eta 0:00:10
#    ------------------------------ --------- 115.9/149.9 MB 3.9 MB/s eta 0:00:09
#    ------------------------------- -------- 117.7/149.9 MB 3.9 MB/s eta 0:00:09
#    ------------------------------- -------- 119.0/149.9 MB 3.9 MB/s eta 0:00:08
#    -------------------------------- ------- 121.1/149.9 MB 4.0 MB/s eta 0:00:08
#    -------------------------------- ------- 123.2/149.9 MB 4.1 MB/s eta 0:00:07
#    --------------------------------- ------ 125.0/149.9 MB 4.1 MB/s eta 0:00:07
#    --------------------------------- ------ 126.9/149.9 MB 4.2 MB/s eta 0:00:06
#    ---------------------------------- ----- 129.0/149.9 MB 4.3 MB/s eta 0:00:05
#    ---------------------------------- ----- 131.1/149.9 MB 4.3 MB/s eta 0:00:05
#    ----------------------------------- ---- 132.6/149.9 MB 4.4 MB/s eta 0:00:04
#    ----------------------------------- ---- 134.7/149.9 MB 4.5 MB/s eta 0:00:04
#    ------------------------------------ --- 136.8/149.9 MB 4.6 MB/s eta 0:00:03
#    ------------------------------------- -- 138.7/149.9 MB 4.6 MB/s eta 0:00:03
#    ------------------------------------- -- 140.5/149.9 MB 4.6 MB/s eta 0:00:03
#    -------------------------------------- - 142.6/149.9 MB 4.7 MB/s eta 0:00:02
#    -------------------------------------- - 143.9/149.9 MB 5.0 MB/s eta 0:00:02
#    -------------------------------------- - 145.2/149.9 MB 5.0 MB/s eta 0:00:01
#    ---------------------------------------  146.8/149.9 MB 5.0 MB/s eta 0:00:01
#    ---------------------------------------  148.9/149.9 MB 5.0 MB/s eta 0:00:01
#    ---------------------------------------  149.7/149.9 MB 5.1 MB/s eta 0:00:01
#    ---------------------------------------  149.7/149.9 MB 5.1 MB/s eta 0:00:01
#    ---------------------------------------- 149.9/149.9 MB 5.0 MB/s eta 0:00:00
# Installing collected packages: xgboost
# Successfully installed xgboost-3.0.3
# Note: you may need to restart the kernel to use updated packages.

# %%
# -----------------------------------------------------------
#  📈 Real-Time Market Price Forecasting
#      (LSTM + XGBoost + ARIMA)
# -----------------------------------------------------------

import warnings
warnings.filterwarnings("ignore")

import streamlit as st
import pandas as pd
import numpy as np
import yfinance as yf
from datetime import datetime
import plotly.graph_objects as go
import plotly.express as px
from plotly.subplots import make_subplots

# ML / DL
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
import xgboost as xgb

# Statsmodels for ARIMA
import statsmodels.api as sm

# -----------------------------------------------------------
# Page Config & Custom CSS
# -----------------------------------------------------------
st.set_page_config(layout="wide", page_title="Market Forecasting Dashboard")

# Custom CSS for enhanced styling
st.markdown("""
<style>
    .metric-card {
        background: linear-gradient(135deg, #667eea 0%, #764ba2 100%);
        padding: 1rem;
        border-radius: 10px;
        color: white;
        margin: 0.5rem 0;
    }
    .bullish { color: #00C851 !important; font-weight: bold; }
    .bearish { color: #FF4444 !important; font-weight: bold; }
    .neutral { color: #33b5e5 !important; font-weight: bold; }
    .alert-box {
        padding: 1rem;
        border-radius: 8px;
        margin: 1rem 0;
        border-left: 5px solid;
    }
    .alert-success { background-color: #d4edda; border-color: #28a745; }
    .alert-warning { background-color: #fff3cd; border-color: #ffc107; }
    .alert-danger { background-color: #f8d7da; border-color: #dc3545; }
</style>
""", unsafe_allow_html=True)

st.title("📈 Real-Time Market Price Forecasting Dashboard")
st.markdown("*Advanced AI-Powered Stock Prediction with LSTM, XGBoost & ARIMA*")

# -----------------------------------------------------------
# Sidebar – Enhanced Inputs
# -----------------------------------------------------------
st.sidebar.header("📊 Configuration")

# Stock selection with popular options
popular_stocks = {
    "TATAMOTORS.NS": "Tata Motors",
    "RELIANCE.NS": "Reliance Industries",
    "TCS.NS": "Tata Consultancy Services",
    "INFY.NS": "Infosys",
    "HDFCBANK.NS": "HDFC Bank",
    "AAPL": "Apple Inc.",
    "MSFT": "Microsoft Corp.",
    "GOOGL": "Alphabet Inc.",
    "TSLA": "Tesla Inc."
}

stock_option = st.sidebar.selectbox(
    "Select Stock:",
    options=list(popular_stocks.keys()),
    format_func=lambda x: f"{x} - {popular_stocks[x]}",
    index=0
)

custom_ticker = st.sidebar.text_input("Or Enter Custom Symbol:", "")
ticker = custom_ticker if custom_ticker else stock_option

start_date = st.sidebar.date_input("Start Date", datetime(2022, 1, 1))
forecast_days = st.sidebar.slider("Days to Predict", 1, 30, 5)

# Alert System
st.sidebar.subheader("🚨 Price Alerts")
alert_enabled = st.sidebar.checkbox("Enable Price Alerts")
if alert_enabled:
    alert_upper = st.sidebar.number_input("Alert if price goes above:", value=700.0, step=10.0)
    alert_lower = st.sidebar.number_input("Alert if price goes below:", value=600.0, step=10.0)

# Display options
st.sidebar.subheader("📈 Display Options")
show_confidence = st.sidebar.checkbox("Show Confidence Intervals", True)
chart_theme = st.sidebar.selectbox("Chart Theme", ["plotly", "plotly_white", "plotly_dark"], index=1)
chart_height = st.sidebar.slider("Chart Height", 300, 600, 400)

# -----------------------------------------------------------
# Helper Functions
# -----------------------------------------------------------
def get_trend_indicator(current, previous):
    """Get trend direction with color and arrow"""
    if current > previous:
        return "📈", "bullish", (current - previous) / previous * 100
    elif current < previous:
        return "📉", "bearish", (current - previous) / previous * 100
    else:
        return "➡️", "neutral", 0

def calculate_support_resistance(df, window=20):
    """Calculate support and resistance levels"""
    highs = df['Close'].rolling(window=window).max()
    lows = df['Close'].rolling(window=window).min()
    
    resistance = highs.iloc[-window:].max()
    support = lows.iloc[-window:].min()
    
    return support, resistance

def get_model_confidence(predictions_df):
    """Calculate confidence scores for each model"""
    volatility = predictions_df.std()
    max_vol = volatility.max()
    
    # Inverse relationship: lower volatility = higher confidence
    confidence = {}
    for col in predictions_df.columns:
        if 'Prediction' in col:
            model_name = col.replace('_Prediction', '')
            conf_score = max(0, 100 - (volatility[col] / max_vol * 100))
            confidence[model_name] = min(100, conf_score)
    
    return confidence

def generate_trading_signal(consensus_trend, confidence_avg, volatility):
    """Generate trading recommendations"""
    if confidence_avg >= 70:
        if consensus_trend > 2:
            return "🟢 STRONG BUY", "alert-success"
        elif consensus_trend > 0.5:
            return "🟢 BUY", "alert-success"
        elif consensus_trend < -2:
            return "🔴 STRONG SELL", "alert-danger"
        elif consensus_trend < -0.5:
            return "🔴 SELL", "alert-danger"
        else:
            return "🟡 HOLD", "alert-warning"
    else:
        return "⚪ UNCERTAIN - Low Confidence", "alert-warning"

# -----------------------------------------------------------
# Load data with error handling and info display
# -----------------------------------------------------------
@st.cache_data
def load_data(ticker, start_date):
    try:
        df = yf.download(ticker,
                         start=start_date,
                         end=pd.to_datetime("today").strftime('%Y-%m-%d'))
        if df.empty:
            st.error(f"No data found for ticker: {ticker}")
            return None
        df = df[['Close']].dropna()
        df.columns = df.columns.droplevel(1)
        return df
    except Exception as e:
        st.error(f"Error loading data: {str(e)}")
        return None

# Display loading message
with st.spinner(f'Loading data for {ticker}...'):
    df = load_data(ticker, start_date)

if df is None or df.empty:
    st.stop()

# Calculate support/resistance and trends
support, resistance = calculate_support_resistance(df)
current_price = df['Close'].iloc[-1]
previous_price = df['Close'].iloc[-2] if len(df) > 1 else current_price
trend_arrow, trend_class, trend_pct = get_trend_indicator(current_price, previous_price)

# Enhanced Stock Info Display
st.markdown("### 📊 Market Overview")
col1, col2, col3, col4, col5 = st.columns(5)

with col1:
    st.markdown(f"""
    <div class="metric-card">
        <h4>Current Price</h4>
        <h2>₹{current_price:.2f}</h2>
        <p>{trend_arrow} <span class="{trend_class}">{trend_pct:+.2f}%</span></p>
    </div>
    """, unsafe_allow_html=True)

with col2:
    change = current_price - previous_price
    st.markdown(f"""
    <div class="metric-card">
        <h4>Daily Change</h4>
        <h2>₹{change:+.2f}</h2>
        <p class="{trend_class}">({trend_pct:+.2f}%)</p>
    </div>
    """, unsafe_allow_html=True)

with col3:
    st.markdown(f"""
    <div class="metric-card">
        <h4>Support Level</h4>
        <h2>₹{support:.2f}</h2>
        <p>📊 Key Level</p>
    </div>
    """, unsafe_allow_html=True)

with col4:
    st.markdown(f"""
    <div class="metric-card">
        <h4>Resistance Level</h4>
        <h2>₹{resistance:.2f}</h2>
        <p>🎯 Target</p>
    </div>
    """, unsafe_allow_html=True)

with col5:
    volatility = df['Close'].pct_change().std() * 100
    vol_color = "bearish" if volatility > 3 else "bullish" if volatility < 1.5 else "neutral"
    st.markdown(f"""
    <div class="metric-card">
        <h4>Volatility</h4>
        <h2 class="{vol_color}">{volatility:.2f}%</h2>
        <p>📈 Risk Level</p>
    </div>
    """, unsafe_allow_html=True)

# Price Alerts Check
if alert_enabled:
    if current_price >= alert_upper:
        st.markdown(f"""
        <div class="alert-box alert-danger">
            🚨 <strong>PRICE ALERT!</strong> Current price ₹{current_price:.2f} is above your alert level of ₹{alert_upper:.2f}
        </div>
        """, unsafe_allow_html=True)
    elif current_price <= alert_lower:
        st.markdown(f"""
        <div class="alert-box alert-danger">
            🚨 <strong>PRICE ALERT!</strong> Current price ₹{current_price:.2f} is below your alert level of ₹{alert_lower:.2f}
        </div>
        """, unsafe_allow_html=True)

# ############################################################
# LSTM SECTION
# ############################################################
sequence_length = 60

def prepare_lstm_data(df):
    scaler = MinMaxScaler(feature_range=(0, 1))
    scaled = scaler.fit_transform(df.values)
    X, y = [], []
    for i in range(sequence_length, len(scaled)):
        X.append(scaled[i - sequence_length:i, 0])
        y.append(scaled[i, 0])
    X, y = np.array(X), np.array(y)
    X = np.reshape(X, (X.shape[0], X.shape[1], 1))
    return X, y, scaler

X_train, y_train, lstm_scaler = prepare_lstm_data(df)

def build_lstm():
    model = Sequential()
    model.add(LSTM(50, return_sequences=True, input_shape=(X_train.shape[1], 1)))
    model.add(Dropout(0.2))
    model.add(LSTM(50))
    model.add(Dropout(0.2))
    model.add(Dense(1))
    model.compile(optimizer='adam', loss='mean_squared_error')
    return model

lstm_model = build_lstm()
with st.spinner('Training LSTM model...'):
    lstm_model.fit(X_train, y_train, epochs=5, batch_size=32, verbose=0)

def predict_lstm(days):
    seq = lstm_scaler.transform(df[-sequence_length:])
    seq = seq.reshape(1, sequence_length, 1)

    preds = []
    for _ in range(days):
        p = lstm_model.predict(seq, verbose=0)[0][0]
        preds.append(p)
        seq = np.append(seq[:, 1:, :], [[[p]]], axis=1)

    preds = lstm_scaler.inverse_transform(np.array(preds).reshape(-1, 1))
    dates = pd.date_range(start=df.index[-1] + pd.Timedelta(days=1), periods=days, freq='D')
    return pd.DataFrame(preds, index=dates, columns=["LSTM_Prediction"])

lstm_preds = predict_lstm(forecast_days)

# ############################################################
# XGBoost SECTION
# ############################################################
def create_xgb_features(df, lags=[1, 2, 3, 5, 7, 10]):
    feat = df.copy()
    for l in lags:
        feat[f'lag_{l}'] = feat['Close'].shift(l)
    feat['ma_5']  = feat['Close'].rolling(5).mean()
    feat['ma_10'] = feat['Close'].rolling(10).mean()
    return feat.dropna()

def train_xgb(df):
    df_feat = create_xgb_features(df)
    X = df_feat.drop(columns=['Close'])
    y = df_feat['Close']
    model = xgb.XGBRegressor(n_estimators=200,
                             learning_rate=0.05,
                             max_depth=4,
                             subsample=0.8,
                             colsample_bytree=0.8,
                             random_state=42)
    model.fit(X, y)
    return model, X.columns

xgb_model, feat_cols = train_xgb(df)

def predict_xgb(days):
    preds = []
    tmp_df = df.copy()

    for _ in range(days):
        feat_df = create_xgb_features(tmp_df)
        row = feat_df.iloc[-1:][feat_cols]
        p = xgb_model.predict(row)[0]
        preds.append(p)

        new_idx = tmp_df.index[-1] + pd.Timedelta(days=1)
        tmp_df = pd.concat([tmp_df,
                            pd.DataFrame({'Close': p}, index=[new_idx])])

    dates = pd.date_range(start=df.index[-1] + pd.Timedelta(days=1), periods=days, freq='D')
    return pd.DataFrame({'XGBoost_Prediction': preds}, index=dates)

xgb_preds = predict_xgb(forecast_days)

# ############################################################
# ARIMA SECTION
# ############################################################
def fit_arima(df, p=5, d=1, q=0):
    model = sm.tsa.ARIMA(df['Close'], order=(p, d, q))
    model_fit = model.fit()
    return model_fit

arima_model = fit_arima(df)

def predict_arima(days):
    forecast = arima_model.forecast(steps=days)
    dates = pd.date_range(start=df.index[-1] + pd.Timedelta(days=1), periods=days, freq='D')
    return pd.DataFrame({'ARIMA_Prediction': forecast.values}, index=dates)

arima_preds = predict_arima(forecast_days)

# ############################################################
# Performance Metrics & Confidence Scores
# ############################################################
def calculate_metrics(actual, predicted):
    mse = np.mean((actual - predicted) ** 2)
    rmse = np.sqrt(mse)
    mae = np.mean(np.abs(actual - predicted))
    mape = np.mean(np.abs((actual - predicted) / actual)) * 100
    return {'MSE': mse, 'RMSE': rmse, 'MAE': mae, 'MAPE': mape}

def get_model_performance():
    lstm_train_pred = lstm_model.predict(X_train, verbose=0)
    lstm_train_pred = lstm_scaler.inverse_transform(lstm_train_pred)
    lstm_actual = lstm_scaler.inverse_transform(y_train.reshape(-1, 1))
    lstm_metrics = calculate_metrics(lstm_actual.flatten(), lstm_train_pred.flatten())
    
    return {'LSTM': lstm_metrics}

performance_metrics = get_model_performance()

# Calculate model confidence scores
all_predictions = pd.DataFrame({
    'LSTM_Prediction': lstm_preds['LSTM_Prediction'].values,
    'XGBoost_Prediction': xgb_preds['XGBoost_Prediction'].values,
    'ARIMA_Prediction': arima_preds['ARIMA_Prediction'].values
})

confidence_scores = get_model_confidence(all_predictions)

# ############################################################
# Technical Indicators
# ############################################################
def add_technical_indicators(df):
    df = df.copy()
    df['SMA_20'] = df['Close'].rolling(window=20).mean()
    df['SMA_50'] = df['Close'].rolling(window=50).mean()
    
    rolling_mean = df['Close'].rolling(window=20).mean()
    rolling_std = df['Close'].rolling(window=20).std()
    df['BB_Upper'] = rolling_mean + (rolling_std * 2)
    df['BB_Lower'] = rolling_mean - (rolling_std * 2)
    
    delta = df['Close'].diff()
    gain = (delta.where(delta > 0, 0)).rolling(window=14).mean()
    loss = (-delta.where(delta < 0, 0)).rolling(window=14).mean()
    rs = gain / loss
    df['RSI'] = 100 - (100 / (1 + rs))
    
    return df

df_with_indicators = add_technical_indicators(df)

# ############################################################
# Enhanced Plotly Charts
# ############################################################
def create_enhanced_forecast_chart(historical_df, prediction_df, title, color_scheme):
    fig = go.Figure()
    
    # Historical data
    fig.add_trace(go.Scatter(
        x=historical_df.index,
        y=historical_df['Close'],
        mode='lines',
        name='Historical',
        line=dict(color=color_scheme['historical'], width=2),
        hovertemplate='Date: %{x}<br>Price: ₹%{y:.2f}<extra></extra>'
    ))
    
    # Predictions
    pred_col = prediction_df.columns[0]
    fig.add_trace(go.Scatter(
        x=prediction_df.index,
        y=prediction_df[pred_col],
        mode='lines+markers',
        name='Forecast',
        line=dict(color=color_scheme['prediction'], width=3, dash='dot'),
        marker=dict(size=8, color=color_scheme['prediction']),
        hovertemplate='Date: %{x}<br>Predicted: ₹%{y:.2f}<extra></extra>'
    ))
    
    # Add support/resistance lines
    fig.add_hline(y=support, line_dash="dash", line_color="green", 
                  annotation_text="Support", annotation_position="bottom right")
    fig.add_hline(y=resistance, line_dash="dash", line_color="red", 
                  annotation_text="Resistance", annotation_position="top right")
    
    fig.update_layout(
        title=title,
        template=chart_theme,
        height=chart_height,
        showlegend=True,
        hovermode='x unified',
        xaxis_title="Date",
        yaxis_title="Price (₹)"
    )
    
    return fig

# ############################################################
# Trading Signals & Analysis
# ############################################################
# Calculate consensus
consensus_pred = all_predictions.mean(axis=1)
consensus_trend = (consensus_pred.iloc[-1] - current_price) / current_price * 100
confidence_avg = np.mean(list(confidence_scores.values()))

# Generate trading signal
trading_signal, signal_class = generate_trading_signal(consensus_trend, confidence_avg, volatility)

# Display Trading Signal
st.markdown("### 🎯 AI Trading Recommendation")
st.markdown(f"""
<div class="alert-box {signal_class}">
    <h3>{trading_signal}</h3>
    <p><strong>Consensus Trend:</strong> {consensus_trend:+.2f}%</p>
    <p><strong>Average Confidence:</strong> {confidence_avg:.1f}%</p>
    <p><strong>Risk Level:</strong> {vol_color.title()} Volatility ({volatility:.2f}%)</p>
</div>
""", unsafe_allow_html=True)

# ############################################################
# Streamlit Display – Enhanced Tabs
# ############################################################
tab1, tab2, tab3, tab4, tab5 = st.tabs(["🔮 LSTM", "🚀 XGBoost", "📊 ARIMA", "📈 Technical Analysis", "⚡ Dashboard"])

color_schemes = {
    'lstm': {'historical': '#1f77b4', 'prediction': '#ff7f0e'},
    'xgboost': {'historical': '#2ca02c', 'prediction': '#d62728'},
    'arima': {'historical': '#9467bd', 'prediction': '#8c564b'}
}

with tab1:
    col1, col2 = st.columns([3, 1])
    
    with col1:
        st.subheader("📈 LSTM Deep Learning Forecast")
        lstm_chart = create_enhanced_forecast_chart(df, lstm_preds, "LSTM Neural Network Prediction", color_schemes['lstm'])
        st.plotly_chart(lstm_chart, use_container_width=True)
    
    with col2:
        st.subheader("Model Performance")
        # Calculate average price for percentage conversion
        avg_price = df['Close'].mean()
        
        # Convert RMSE and MAE to percentages
        rmse_pct = (performance_metrics['LSTM']['RMSE'] / avg_price) * 100
        mae_pct = (performance_metrics['LSTM']['MAE'] / avg_price) * 100
        
        st.metric("RMSE", f"{rmse_pct:.2f}%")
        st.metric("MAE", f"{mae_pct:.2f}%")
        st.metric("MAPE", f"{performance_metrics['LSTM']['MAPE']:.2f}%")
        
        # Confidence Score
        lstm_conf = confidence_scores.get('LSTM', 0)
        conf_color = "🟢" if lstm_conf > 70 else "🟡" if lstm_conf > 50 else "🔴"
        st.metric("Confidence", f"{conf_color} {lstm_conf:.1f}%")
    
    st.subheader("LSTM Prediction Values")
    lstm_display = lstm_preds.copy()
    lstm_display['Trend'] = lstm_display['LSTM_Prediction'].pct_change() * 100
    lstm_display['Signal'] = lstm_display['Trend'].apply(lambda x: "📈" if x > 0 else "📉" if x < 0 else "➡️")
    st.dataframe(lstm_display.round(2), use_container_width=True)

with tab2:
    col1, col2 = st.columns([3, 1])
    
    with col1:
        st.subheader("📊 XGBoost Gradient Boosting Forecast") 
        xgb_chart = create_enhanced_forecast_chart(df, xgb_preds, "XGBoost Machine Learning Prediction", color_schemes['xgboost'])
        st.plotly_chart(xgb_chart, use_container_width=True)
    
    with col2:
        st.subheader("Model Insights")
        xgb_conf = confidence_scores.get('XGBoost', 0)
        conf_color = "🟢" if xgb_conf > 70 else "🟡" if xgb_conf > 50 else "🔴"
        st.metric("Confidence", f"{conf_color} {xgb_conf:.1f}%")
        
        st.subheader("Feature Importance")
        importance = xgb_model.feature_importances_
        feat_imp_df = pd.DataFrame({
            'Feature': feat_cols,
            'Importance': importance
        }).sort_values('Importance', ascending=False).head(5)
        
        for _, row in feat_imp_df.iterrows():
            st.metric(row['Feature'], f"{row['Importance']:.3f}")
    
    st.subheader("XGBoost Prediction Values")
    xgb_display = xgb_preds.copy()
    xgb_display['Trend'] = xgb_display['XGBoost_Prediction'].pct_change() * 100
    xgb_display['Signal'] = xgb_display['Trend'].apply(lambda x: "📈" if x > 0 else "📉" if x < 0 else "➡️")
    st.dataframe(xgb_display.round(2), use_container_width=True)

with tab3:
    col1, col2 = st.columns([3, 1])
    
    with col1:
        st.subheader("📉 ARIMA Time Series Forecast")
        arima_chart = create_enhanced_forecast_chart(df, arima_preds, "ARIMA Statistical Prediction", color_schemes['arima'])
        st.plotly_chart(arima_chart, use_container_width=True)
    
    with col2:
        st.subheader("Model Insights")
        arima_conf = confidence_scores.get('ARIMA', 0)
        conf_color = "🟢" if arima_conf > 70 else "🟡" if arima_conf > 50 else "🔴"
        st.metric("Confidence", f"{conf_color} {arima_conf:.1f}%")
        
        st.subheader("Model Info")
        st.info("ARIMA (5,1,0) Model\nAutoregressive with differencing")
    
    st.subheader("ARIMA Prediction Values")
    arima_display = arima_preds.copy()
    arima_display['Trend'] = arima_display['ARIMA_Prediction'].pct_change() * 100
    arima_display['Signal'] = arima_display['Trend'].apply(lambda x: "📈" if x > 0 else "📉" if x < 0 else "➡️")
    st.dataframe(arima_display.round(2), use_container_width=True)

with tab4:
    st.subheader("📈 Technical Analysis Dashboard")
    
    # Create technical analysis chart
    fig_tech = make_subplots(rows=3, cols=1, 
                            subplot_titles=('Price & Moving Averages', 'Bollinger Bands', 'RSI'),
                            vertical_spacing=0.08,
                            row_heights=[0.5, 0.3, 0.2])
    
    # Price and Moving Averages
    recent_data = df_with_indicators.tail(100)
    fig_tech.add_trace(go.Scatter(x=recent_data.index, y=recent_data['Close'], 
                                 name='Close Price', line=dict(color='blue', width=2)), row=1, col=1)
    fig_tech.add_trace(go.Scatter(x=recent_data.index, y=recent_data['SMA_20'], 
                                 name='SMA 20', line=dict(color='orange', width=1)), row=1, col=1)
    fig_tech.add_trace(go.Scatter(x=recent_data.index, y=recent_data['SMA_50'], 
                                 name='SMA 50', line=dict(color='red', width=1)), row=1, col=1)
    
    # Bollinger Bands
    fig_tech.add_trace(go.Scatter(x=recent_data.index, y=recent_data['BB_Upper'], 
                                 name='BB Upper', line=dict(color='gray', dash='dash')), row=2, col=1)
    fig_tech.add_trace(go.Scatter(x=recent_data.index, y=recent_data['Close'], 
                                 name='Price', line=dict(color='blue')), row=2, col=1)
    fig_tech.add_trace(go.Scatter(x=recent_data.index, y=recent_data['BB_Lower'], 
                                 name='BB Lower', line=dict(color='gray', dash='dash')), row=2, col=1)
    
    # RSI
    fig_tech.add_trace(go.Scatter(x=recent_data.index, y=recent_data['RSI'], 
                                 name='RSI', line=dict(color='purple')), row=3, col=1)
    fig_tech.add_hline(y=70, line_dash="dash", line_color="red", row=3, col=1)
    fig_tech.add_hline(y=30, line_dash="dash", line_color="green", row=3, col=1)
    
    fig_tech.update_layout(height=800, template=chart_theme, showlegend=False)
    st.plotly_chart(fig_tech, use_container_width=True)
    
    # Technical Analysis Summary
    col1, col2, col3 = st.columns(3)
    
    current_rsi = df_with_indicators['RSI'].iloc[-1]
    sma_20 = df_with_indicators['SMA_20'].iloc[-1]
    sma_50 = df_with_indicators['SMA_50'].iloc[-1]
    
    with col1:
        rsi_signal = "🔴 Overbought" if current_rsi > 70 else "🟢 Oversold" if current_rsi < 30 else "🟡 Neutral"
        st.metric("RSI Signal", rsi_signal, f"{current_rsi:.1f}")
    
    with col2:
        ma_signal = "🟢 Bullish" if current_price > sma_20 > sma_50 else "🔴 Bearish" if current_price < sma_20 < sma_50 else "🟡 Mixed"
        st.metric("MA Signal", ma_signal)
    
    with col3:
        bb_position = "Upper" if current_price > df_with_indicators['BB_Upper'].iloc[-1] else "Lower" if current_price < df_with_indicators['BB_Lower'].iloc[-1] else "Middle"
        st.metric("BB Position", f"🎯 {bb_position}")

with tab5:
    st.subheader("⚡ Real-time Dashboard")
    
    # Auto-refresh button
    col1, col2, col3 = st.columns([1, 1, 2])
    with col1:
        if st.button("🔄 Refresh Data", type="primary"):
            st.cache_data.clear()
            st.rerun()
    
    with col2:
        auto_refresh = st.checkbox("Auto Refresh (30s)")
        if auto_refresh:
            st.rerun()
    
    # Real-time metrics with enhanced styling
    st.markdown("#### 📊 Live Market Metrics")
    col1, col2, col3, col4 = st.columns(4)
    
    with col1:
        last_update = df.index[-1].strftime("%H:%M")
        st.metric("Last Update", last_update, "Live")
    
    with col2:
        market_cap = "N/A"  # Would need additional API for real market cap
        st.metric("Market Status", "🟢 Open" if datetime.now().hour < 16 else "🔴 Closed")
    
    with col3:
        volume_trend = "📈 High" if volatility > 2 else "📊 Normal"
        st.metric("Activity", volume_trend)
    
    with col4:
        data_quality = "🟢 Good" if len(df) > 100 else "🟡 Limited"
        st.metric("Data Quality", data_quality, f"{len(df)} points")
    
    # Recent price movements
    st.markdown("#### 📈 Recent Price Action (Last 10 Days)")
    recent_data = df.tail(10).copy()
    recent_data['Daily_Change'] = recent_data['Close'].pct_change() * 100
    recent_data['Direction'] = recent_data['Daily_Change'].apply(
        lambda x: "🟢" if x > 0 else "🔴" if x < 0 else "⚪"
    )
    recent_data['Trend_Class'] = recent_data['Daily_Change'].apply(
        lambda x: "bullish" if x > 0 else "bearish" if x < 0 else "neutral"
    )
    
    # Display recent data with color coding
    st.dataframe(
        recent_data[['Close', 'Daily_Change', 'Direction']].round(2).style.format({
            'Close': '₹{:.2f}',
            'Daily_Change': '{:+.2f}%'
        }),
        use_container_width=True
    )

# ############################################################
# Enhanced Summary Section with Trading Insights
# ############################################################
st.markdown("---")
st.header("📊 Comprehensive AI Analysis")

# Model predictions comparison with enhanced visualization
col1, col2 = st.columns([2, 1])

with col1:
    st.subheader("🔮 All Model Predictions Comparison")
    
    # Create comparison chart
    fig_comparison = go.Figure()
    
    # Historical data (last 30 days for context)
    historical_recent = df.tail(30)
    fig_comparison.add_trace(go.Scatter(
        x=historical_recent.index,
        y=historical_recent['Close'],
        mode='lines',
        name='Historical',
        line=dict(color='#1f77b4', width=2),
        hovertemplate='Date: %{x}<br>Price: ₹%{y:.2f}<extra></extra>'
    ))
    
    # Model predictions
    colors = ['#ff7f0e', '#2ca02c', '#d62728']
    models = ['LSTM', 'XGBoost', 'ARIMA']
    predictions = [lstm_preds['LSTM_Prediction'], xgb_preds['XGBoost_Prediction'], arima_preds['ARIMA_Prediction']]
    
    for i, (model, pred, color) in enumerate(zip(models, predictions, colors)):
        fig_comparison.add_trace(go.Scatter(
            x=pred.index,
            y=pred.values,
            mode='lines+markers',
            name=f'{model} Forecast',
            line=dict(color=color, width=2, dash='dot'),
            marker=dict(size=6),
            hovertemplate=f'{model}: %{{y:.2f}}<extra></extra>'
        ))
    
    # Add support/resistance lines
    fig_comparison.add_hline(y=support, line_dash="dash", line_color="green", 
                           annotation_text="Support ₹{:.2f}".format(support))
    fig_comparison.add_hline(y=resistance, line_dash="dash", line_color="red", 
                           annotation_text="Resistance ₹{:.2f}".format(resistance))
    
    fig_comparison.update_layout(
        template=chart_theme,
        height=500,
        showlegend=True,
        hovermode='x unified',
        xaxis_title="Date",
        yaxis_title="Price (₹)",
        title="Multi-Model Forecast Comparison"
    )
    
    st.plotly_chart(fig_comparison, use_container_width=True)

with col2:
    st.subheader("🎯 Model Consensus")
    
    # Calculate consensus metrics
    avg_prediction = all_predictions.mean(axis=1)
    std_prediction = all_predictions.std(axis=1)
    
    # Display consensus for each day
    for i, date in enumerate(all_predictions.index):
        trend_arrow = "📈" if avg_prediction.iloc[i] > current_price else "📉"
        confidence_level = "High" if std_prediction.iloc[i] < current_price * 0.02 else "Medium" if std_prediction.iloc[i] < current_price * 0.05 else "Low"
        
        st.markdown(f"""
        **Day {i+1}** {trend_arrow}  
        **Price:** ₹{avg_prediction.iloc[i]:.2f}  
        **Range:** ±₹{std_prediction.iloc[i]:.2f}  
        **Confidence:** {confidence_level}
        ---
        """)

# Model Agreement Analysis with enhanced metrics
st.subheader("🤖 Model Intelligence Analysis")
col1, col2, col3, col4 = st.columns(4)

# Calculate advanced metrics
agreement_df = all_predictions.copy()
agreement_df['Range'] = agreement_df.max(axis=1) - agreement_df.min(axis=1)
agreement_df['Consensus'] = agreement_df.mean(axis=1)
avg_range = agreement_df['Range'].mean()
max_consensus = agreement_df['Consensus'].max()
trend_direction = "📈 Bullish" if agreement_df['Consensus'].iloc[-1] > agreement_df['Consensus'].iloc[0] else "📉 Bearish"

# Calculate model agreement score
agreement_score = max(0, 100 - (avg_range / current_price * 100))

with col1:
    st.metric("Avg Prediction Range", f"₹{avg_range:.2f}", 
             f"{avg_range/current_price*100:.1f}% of price")

with col2:
    st.metric("Highest Consensus", f"₹{max_consensus:.2f}")

with col3:
    st.metric("Overall Trend", trend_direction)

with col4:
    agreement_color = "🟢" if agreement_score > 80 else "🟡" if agreement_score > 60 else "🔴"
    st.metric("Agreement Score", f"{agreement_color} {agreement_score:.1f}%")

# Enhanced Risk Assessment with actionable insights
st.subheader("⚠️ Risk Assessment & Investment Guidance")
col1, col2, col3 = st.columns(3)

with col1:
    # Volatility risk with actionable advice
    if volatility > 3:
        risk_level = "🔴 HIGH RISK"
        advice = "Consider smaller position sizes"
    elif volatility > 1.5:
        risk_level = "🟡 MODERATE RISK" 
        advice = "Standard position sizing"
    else:
        risk_level = "🟢 LOW RISK"
        advice = "Good for larger positions"
    
    st.markdown(f"""
    **Volatility Analysis**  
    {risk_level}: {volatility:.2f}%  
    *{advice}*
    """)

with col2:
    # Model disagreement risk
    if avg_range > current_price * 0.05:
        disagreement_level = "🔴 HIGH DISAGREEMENT"
        model_advice = "Wait for clearer signals"
    elif avg_range > current_price * 0.02:
        disagreement_level = "🟡 MODERATE DISAGREEMENT"
        model_advice = "Use caution, smaller sizes"
    else:
        disagreement_level = "🟢 GOOD AGREEMENT"
        model_advice = "Models align well"
    
    st.markdown(f"""
    **Model Consensus**  
    {disagreement_level}  
    *{model_advice}*
    """)

with col3:
    # Data recency and quality
    days_since_update = (pd.to_datetime("today") - df.index[-1]).days
    if days_since_update > 1:
        data_status = "🟡 DATA AGING"
        data_advice = f"Data is {days_since_update} days old"
    else:
        data_status = "🟢 DATA CURRENT"
        data_advice = "Fresh market data"
    
    st.markdown(f"""
    **Data Quality**  
    {data_status}  
    *{data_advice}*
    """)

# Final Investment Summary
st.markdown("---")
st.markdown("### 💡 Investment Summary")

# Calculate final recommendation score
recommendation_score = (confidence_avg + agreement_score) / 2
price_target = avg_prediction.iloc[-1]
potential_return = (price_target - current_price) / current_price * 100

if recommendation_score >= 75 and abs(potential_return) > 2:
    if potential_return > 0:
        final_recommendation = "🟢 STRONG BUY SIGNAL"
        recommendation_class = "alert-success"
    else:
        final_recommendation = "🔴 STRONG SELL SIGNAL" 
        recommendation_class = "alert-danger"
elif recommendation_score >= 60:
    if potential_return > 1:
        final_recommendation = "🟢 BUY SIGNAL"
        recommendation_class = "alert-success"
    elif potential_return < -1:
        final_recommendation = "🔴 SELL SIGNAL"
        recommendation_class = "alert-danger"
    else:
        final_recommendation = "🟡 HOLD POSITION"
        recommendation_class = "alert-warning"
else:
    final_recommendation = "⚪ UNCERTAIN - WAIT"
    recommendation_class = "alert-warning"

st.markdown(f"""
<div class="alert-box {recommendation_class}">
    <h2>{final_recommendation}</h2>
    <div style="display: flex; justify-content: space-between; margin-top: 1rem;">
        <div>
            <strong>Target Price:</strong> ₹{price_target:.2f}<br>
            <strong>Potential Return:</strong> {potential_return:+.2f}%<br>
            <strong>Time Horizon:</strong> {forecast_days} days
        </div>
        <div>
            <strong>Confidence:</strong> {confidence_avg:.1f}%<br>
            <strong>Agreement:</strong> {agreement_score:.1f}%<br>
            <strong>Overall Score:</strong> {recommendation_score:.1f}%
        </div>
    </div>
</div>
""", unsafe_allow_html=True)

# Key levels for traders
st.markdown("#### 🎯 Key Trading Levels")
col1, col2, col3, col4 = st.columns(4)

with col1:
    st.metric("Entry Level", f"₹{current_price:.2f}", "Current")

with col2: 
    stop_loss = current_price * 0.95 if potential_return > 0 else current_price * 1.05
    st.metric("Stop Loss", f"₹{stop_loss:.2f}", f"{-5 if potential_return > 0 else 5}%")

with col3:
    st.metric("Target 1", f"₹{price_target:.2f}", f"{potential_return:+.1f}%")

with col4:
    target_2 = price_target * 1.1 if potential_return > 0 else price_target * 0.9
    extended_return = (target_2 - current_price) / current_price * 100
    st.metric("Target 2", f"₹{target_2:.2f}", f"{extended_return:+.1f}%")
# Out:
# 2025-08-03 19:25:43.525 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:43.528 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:43.773
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run E:\Anaconda\envs\Spark\Lib\site-packages\ipykernel_launcher.py [ARGUMENTS]
# 2025-08-03 19:25:43.773 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:43.774 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:43.775 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:43.775 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:43.777 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:43.778 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:43.779 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:43.779 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:43.780 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:43.780 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:43.781 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:43.783 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:43.784 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:43.785 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:43.787 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:43.788 Session state does not function when running a script without `streamlit run`
# 2025-08-03 19:25:43.789 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:43.789 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:43.790 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:43.791 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:43.791 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:43.792 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:43.793 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:43.794 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:43.794 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:43.795 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:43.796 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:43.796 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:43.797 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:43.798 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:43.799 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:43.799 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:43.801 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:43.803 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:43.805 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:43.807 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:43.808 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:43.809 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:43.810 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:43.812 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:43.818 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:43.822 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:43.825 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:43.826 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:43.827 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:43.829 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:43.830 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:43.831 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:43.832 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:43.834 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:43.835 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:43.837 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:43.838 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:43.840 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:43.841 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:43.844 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:43.847 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:43.848 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:43.849 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:43.851 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:43.852 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:43.853 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:43.854 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:43.855 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:43.856 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:43.857 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:43.858 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:43.858 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:43.859 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:43.861 No runtime found, using MemoryCacheStorageManager
# 2025-08-03 19:25:43.864 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:43.870 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:43.872 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:43.872 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:43.875 No runtime found, using MemoryCacheStorageManager
# 2025-08-03 19:25:43.876 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:43.876 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:43.877 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:43.878 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:44.384 Thread 'Thread-99': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:44.386 Thread 'Thread-100': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:44.387 Thread 'Thread-99': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:44.390 Thread 'Thread-100': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:44.391 Thread 'Thread-99': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:44.391 Thread 'Thread-100': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# [*********************100%***********************]  1 of 1 completed
# 2025-08-03 19:25:46.215 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:46.216 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:46.217 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:46.217 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:46.218 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:46.219 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:46.226 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:46.227 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:46.228 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:46.229 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:46.230 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:46.230 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:46.231 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:46.232 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:46.233 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:46.234 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:46.236 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:46.237 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:46.238 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:46.238 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:46.240 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:46.241 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:46.241 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:46.242 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:46.243 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:46.243 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:46.244 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:46.247 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:46.248 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:46.248 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:46.576 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:46.577 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:46.577 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:46.578 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:47.092 Thread 'Thread-102': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:47.097 Thread 'Thread-102': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:47.101 Thread 'Thread-102': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:53.131 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:53.132 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:53.133 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# E:\Anaconda\envs\Spark\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# E:\Anaconda\envs\Spark\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# E:\Anaconda\envs\Spark\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# E:\Anaconda\envs\Spark\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# 2025-08-03 19:25:54.917 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:54.918 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:54.918 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:54.919 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:54.919 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:54.920 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:54.920 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:54.921 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:54.922 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:54.922 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:54.923 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:54.923 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:54.924 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:54.924 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:54.925 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:54.925 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:54.926 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:54.927 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:55.639 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:55.640 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:55.641 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:55.641 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:55.642 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:55.643 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:55.643 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:55.644 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:55.645 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:55.646 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:55.647 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:55.647 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:55.648 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:55.648 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:55.649 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:55.650 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:55.650 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:55.651 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:55.651 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:55.652 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:55.653 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:55.653 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:55.654 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:55.707 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:55.708 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:55.709 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:55.713 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:55.714 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:55.716 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:55.717 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:55.718 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:55.719 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:55.787 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:55.788 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:55.789 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:55.790 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:55.790 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:55.791 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:55.792 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:55.793 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:55.794 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:55.794 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:55.795 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:55.796 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:55.796 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:55.797 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:55.802 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:55.804 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:55.805 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:55.807 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:55.808 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:55.809 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:55.810 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:55.810 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:55.811 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:55.812 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:55.812 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:55.813 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:55.814 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:55.814 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:55.815 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:55.816 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:55.816 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:55.817 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:55.823 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:55.824 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:55.824 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:55.827 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:55.828 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:55.829 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:55.830 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:55.831 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:55.832 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:55.880 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:55.881 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:55.882 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:55.883 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:55.883 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:55.885 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:55.886 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:55.887 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:55.888 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:55.889 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:55.890 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:55.890 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:55.891 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:55.892 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:55.894 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:55.895 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:55.896 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:55.897 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:55.898 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:55.900 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:55.905 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:55.905 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:55.906 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:55.907 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:55.908 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:55.909 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:56.018 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:56.019 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:56.019 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:56.020 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:56.020 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:56.021 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:56.021 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:56.022 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:56.022 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:56.023 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:56.023 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:56.024 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:56.024 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:56.025 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:56.026 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:56.027 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:56.028 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:56.028 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:56.029 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:56.030 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:56.031 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:56.031 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:56.032 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:56.032 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:56.033 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:56.033 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:56.034 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:56.034 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:56.035 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:56.036 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:56.036 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:56.037 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:56.037 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:56.038 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:56.039 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:56.040 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:56.041 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:56.042 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:56.042 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:56.043 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:56.046 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:56.047 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:56.047 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:56.048 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:56.048 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:56.049 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:56.050 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:56.051 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:56.052 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:56.052 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:56.053 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:56.054 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:56.055 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:56.055 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:56.056 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:56.057 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:56.057 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:56.058 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:56.059 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:56.059 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:56.172 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:56.201 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:56.201 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:56.202 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:56.203 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:56.204 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:56.204 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:56.205 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:56.205 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:56.205 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:56.206 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:56.206 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:56.207 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:56.208 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:56.209 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:56.210 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:56.255 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:56.256 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:56.258 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:56.259 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:56.260 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:56.261 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:56.262 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:56.263 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:56.265 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:56.266 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:56.266 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:56.266 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:56.267 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:56.267 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:56.268 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:56.268 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:56.269 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:56.269 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:56.270 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:56.270 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:56.271 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:56.271 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:56.272 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:56.272 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:56.273 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:56.273 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:56.274 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:56.274 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:56.275 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:56.275 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:56.276 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:56.279 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:56.280 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:56.280 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:56.281 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:56.282 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:56.282 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:56.283 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:56.284 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:56.284 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:56.285 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:56.285 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:56.286 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:56.286 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:56.287 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:56.287 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:56.288 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:56.288 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:56.288 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:56.289 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:56.289 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:56.290 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:56.290 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:56.291 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:56.292 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:56.292 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:56.293 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:56.294 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:56.294 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:56.295 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:56.295 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:56.296 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:56.296 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:56.297 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:56.297 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:56.298 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:56.299 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:56.299 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:56.299 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:56.300 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:56.300 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:56.301 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:56.301 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:56.302 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:56.303 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:56.303 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:56.304 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:56.304 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:56.305 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:56.305 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:56.306 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:56.306 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:56.307 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:56.307 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:56.308 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:56.309 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:56.309 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 19:25:56.310 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
pip install tensorflow
# Out:
# Requirement already satisfied: tensorflow in e:\anaconda\envs\spark\lib\site-packages (2.19.0)
# Requirement already satisfied: absl-py>=1.0.0 in e:\anaconda\envs\spark\lib\site-packages (from tensorflow) (2.3.1)
# Requirement already satisfied: astunparse>=1.6.0 in e:\anaconda\envs\spark\lib\site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in e:\anaconda\envs\spark\lib\site-packages (from tensorflow) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in e:\anaconda\envs\spark\lib\site-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in e:\anaconda\envs\spark\lib\site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in e:\anaconda\envs\spark\lib\site-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in e:\anaconda\envs\spark\lib\site-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in e:\anaconda\envs\spark\lib\site-packages (from tensorflow) (24.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in e:\anaconda\envs\spark\lib\site-packages (from tensorflow) (5.29.5)
# Requirement already satisfied: requests<3,>=2.21.0 in e:\anaconda\envs\spark\lib\site-packages (from tensorflow) (2.32.4)
# Requirement already satisfied: setuptools in e:\anaconda\envs\spark\lib\site-packages (from tensorflow) (78.1.1)
# Requirement already satisfied: six>=1.12.0 in e:\anaconda\envs\spark\lib\site-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in e:\anaconda\envs\spark\lib\site-packages (from tensorflow) (3.1.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in e:\anaconda\envs\spark\lib\site-packages (from tensorflow) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in e:\anaconda\envs\spark\lib\site-packages (from tensorflow) (1.17.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in e:\anaconda\envs\spark\lib\site-packages (from tensorflow) (1.74.0)
# Requirement already satisfied: tensorboard~=2.19.0 in e:\anaconda\envs\spark\lib\site-packages (from tensorflow) (2.19.0)
# Requirement already satisfied: keras>=3.5.0 in e:\anaconda\envs\spark\lib\site-packages (from tensorflow) (3.11.1)
# Requirement already satisfied: numpy<2.2.0,>=1.26.0 in e:\anaconda\envs\spark\lib\site-packages (from tensorflow) (2.1.3)
# Requirement already satisfied: h5py>=3.11.0 in e:\anaconda\envs\spark\lib\site-packages (from tensorflow) (3.14.0)
# Requirement already satisfied: ml-dtypes<1.0.0,>=0.5.1 in e:\anaconda\envs\spark\lib\site-packages (from tensorflow) (0.5.3)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in e:\anaconda\envs\spark\lib\site-packages (from tensorflow) (0.31.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in e:\anaconda\envs\spark\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in e:\anaconda\envs\spark\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in e:\anaconda\envs\spark\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in e:\anaconda\envs\spark\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (2025.6.15)
# Requirement already satisfied: markdown>=2.6.8 in e:\anaconda\envs\spark\lib\site-packages (from tensorboard~=2.19.0->tensorflow) (3.8.2)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in e:\anaconda\envs\spark\lib\site-packages (from tensorboard~=2.19.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in e:\anaconda\envs\spark\lib\site-packages (from tensorboard~=2.19.0->tensorflow) (3.1.3)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in e:\anaconda\envs\spark\lib\site-packages (from astunparse>=1.6.0->tensorflow) (0.45.1)
# Requirement already satisfied: rich in e:\anaconda\envs\spark\lib\site-packages (from keras>=3.5.0->tensorflow) (14.1.0)
# Requirement already satisfied: namex in e:\anaconda\envs\spark\lib\site-packages (from keras>=3.5.0->tensorflow) (0.1.0)
# Requirement already satisfied: optree in e:\anaconda\envs\spark\lib\site-packages (from keras>=3.5.0->tensorflow) (0.17.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in e:\anaconda\envs\spark\lib\site-packages (from werkzeug>=1.0.1->tensorboard~=2.19.0->tensorflow) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in e:\anaconda\envs\spark\lib\site-packages (from rich->keras>=3.5.0->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in e:\anaconda\envs\spark\lib\site-packages (from rich->keras>=3.5.0->tensorflow) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in e:\anaconda\envs\spark\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow) (0.1.2)
# Note: you may need to restart the kernel to use updated packages.
